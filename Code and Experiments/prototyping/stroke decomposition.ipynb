# %% [markdown]
# # Stroke Decomposition
#
# drive notes: https://docs.google.com/document/d/1XO1u8E0DPgl9g6yaCIBgIzvH90cOMfWVx5ndorhusfU/edit?usp=sharing

# %% [markdown]
# ## Preprocessing
# * Notes
#     * for now it seems that the other morphological processes do not greatly enhance the image, before skeletonization
#     * should try a light blur to try and remove 1x1 holes

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

import cv2
from skimage.morphology import skeletonize, remove_small_holes
import networkx as nx

#module for converting skeleton networks into a graph representation
import sknw

#set dpi
mpl.rcParams['figure.dpi'] = 300
mpl.rcParams['text.color'] = 'yellow'
mpl.rcParams['font.size'] = 5

# %%
eng_test = cv2.imread(r'CERUG_EN_Test.png', cv2.IMREAD_GRAYSCALE)
eng_test = cv2.threshold(eng_test, 0, 1, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1] #threshold and invert image at the same time

#NOTE: imshow reduces the resolution
plt.imshow(eng_test, cmap='gray')

# %%
#test iamge one, here the image is skeletonized as is
eng_test_skele = skeletonize(eng_test)

plt.imshow(eng_test_skele)

# %%
#test image two, small holes (around 1-2px) are considered artefacts here
eng_test_shr = remove_small_holes(eng_test, 4)
eng_test_shr_skele = skeletonize(eng_test_shr)

plt.imshow(eng_test_shr_skele)
# Out:
# /tmp/ipykernel_245036/3557024178.py:2: UserWarning: Any labeled images will be returned as a boolean array. Did you mean to use a boolean array?
#   eng_test_shr = remove_small_holes(eng_test, 4)

# %% [markdown]
# ## Graph Conversion
#
# ### sknw
# source: https://github.com/Image-Py/sknw
#
# notes:
# * experimentation with yxdragons skeleton network library

# %%
#plot image graph of skeletonized text. also made to return graph for futher testing (later)
def plot_image_graph(image, full=True):
    #build graph from skeleton
    graph = sknw.build_sknw(image, multi=True, full=False, ring=True)

    #draw image
    plt.imshow(image, cmap='gray')

    #draw edges by pts
    #edges returns a "multi-edge view". using edges() returns a regular edge view, which doesn't contain identifiers multiple edges
    for (s, e_dict, idx) in graph.edges: 
        ps = graph[s][e_dict][idx]['pts']
        plt.plot(ps[:, 1], ps[:, 0], 'green')


    #draw node by o
    nodes = graph.nodes()
    ps = np.array([nodes[i]['o'] for i in nodes])
    plt.plot(ps[:,1], ps[:,0], 'r.', linewidth=1, markersize=1)

    #annotate nodes
    for node in nodes:
        plt.annotate(str(node), (ps[node, 1], ps[node, 0]))

    #title and show
    plt.title('Build Graph')
    plt.show()

    return graph

# %%
plot_image_graph(eng_test_skele)

# %%
plot_image_graph(eng_test_shr_skele)

# %% [markdown]
# ## Attempt 1 - Simple Graph Based Method
# steps:
# 1. preprocess document
#     * remove small holes
#     * skeletonize image
# 3. find *critical points* and split connected components based on those branches
#     * branching areas indicating stroke overlap
# 5. reconstruct labeled strokes to act as mask for original images
#     * nn clustering used for simplicity
#     * could also use morphological reconstruction if need be

# %%
#going to assume a preprocesed image is fed in
def segment_stroke_fragments(image):
    labels = np.zeros_like(image, dtype=int)

    #can't decide if I should pass in the graph or do it in the function like this
    graph = sknw.build_sknw(image, multi=True, full=False, ring=True)

    #TODO: figure out a way to vectorize the outer portion
    for label_idx, (node1, node2, idx) in enumerate(graph.edges):
        edge_points = graph[node1][node2][idx]['pts']

        labels[edge_points[:, 0], edge_points[:, 1]] = label_idx + 1 #need to account for zero indexing
    
    return labels

# %%
eng_test_skele_labeled = segment_stroke_fragments(eng_test_skele)

plt.imshow(eng_test_skele_labeled, cmap='tab20c')

# %% [markdown]
# * idea is to label the image based on nearest non-zero pixel label
# * knearestneighbors may not be the answer to this. might be something easier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
label_coords = np.array(eng_test_skele_labeled.nonzero()).T

# %%
labels = eng_test_skele_labeled[label_coords[:, 0], label_coords[:, 1]] #not sure if actually required
labels.shape
# Out:
# (843,)

# %%
cls = KNeighborsClassifier(n_neighbors=3)
cls.fit(label_coords, labels)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
img_coords = np.array(eng_test.nonzero()).T
eng_test[img_coords[:, 0], img_coords[:, 1]]
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=uint8)

# %%
img_labels = cls.predict(img_coords)
img_labels
# Out:
# array([ 1,  1,  1, ..., 49, 53, 53])

# %%
labeled_image = np.zeros_like(eng_test, dtype=int)
labeled_image[img_coords[:, 0], img_coords[:, 1]] = img_labels
plt.imshow(labeled_image)

# %%
mpl.rcParams['text.color'] = 'black'

#figure for presentation
fig, axes = plt.subplots(2, 2)

#original image
eng_test_orig = cv2.imread("CERUG_EN_Test.png")
axes[0, 0].imshow(eng_test_orig)
axes[0, 0].set_title("original")
axes[0, 0].axis("off")

#preprocessed
axes[0, 1].imshow(eng_test_shr_skele, cmap='gray')
axes[0, 1].set_title("preprocesed and skeletonized")
axes[0, 1].axis("off")

#graph representation
axes[1, 0].imshow(eng_test_skele_labeled, interpolation="nearest")
axes[1, 0].set_title("stroke fragments segmented and labeled")
axes[1, 0].axis("off")

# region growing?
axes[1, 1].imshow(labeled_image, interpolation="nearest")
axes[1, 1].set_title("orignal image labeled through k-nearest neighbor")
axes[1, 1].axis("off")

padding = 0.01
fig.subplots_adjust(wspace=padding, hspace=-.5)
fig.suptitle("Simple Graph Segmentation Method")
# Out:
# Text(0.5, 0.98, 'Simple Graph Segmentation Method')

# %% [markdown]
# # Stroke Segmentation by region growing with nodes and edges, then merging

# %%
plt.imshow(eng_test_skele)

# %%
import sknw
eng_graph = sknw.build_sknw(eng_test_skele, multi=True, full=False)

eng_graph

# %%
from qdanalysis.strokedecomposition import label_graph_edges_and_nodes

# %%
label_img = label_graph_edges_and_nodes(eng_graph, eng_test.shape)
plt.imshow(label_img)

# %%
from matplotlib.colors import ListedColormap

unique_colors = np.unique(label_img)
print("number of colors: ", len(unique_colors))

colors = plt.cm.get_cmap('hsv', len(unique_colors))
custom_cmap = ListedColormap(colors(np.linspace(0, 1, len(unique_colors))))
custom_cmap
# Out:
# number of colors:  71
# /tmp/ipykernel_245036/539399336.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('hsv', len(unique_colors))

# %%
plt.matshow(label_img, cmap='tab20c')

# #display number values
# for (i, j), val in np.ndenumerate(label_img):
#     ax.text(j, i, f'{val}', ha='center', va='center', color='white')


plt.colorbar()
plt.show()

# %%
from qdanalysis.strokedecomposition import knnRegionGrowth
grown_region = knnRegionGrowth(label_img, eng_test)

# %%
plt.imshow(grown_region)

# %%
def show_label_segment(img, label):
    filtered_image = np.copy(img)
    filtered_image[filtered_image != label] = 0
    plt.imshow(filtered_image)

# %%
show_label_segment(grown_region, 80)

# %%
plt.imshow(eng_test)

# draw node by o
nodes = eng_graph.nodes()
ps = np.array([nodes[i]['o'] for i in nodes])
plt.plot(ps[:,1], ps[:,0], 'r.')
plt.show()

# %%
test = cv2.imread('CERUG_EN_Test.png')

test.shape
# Out:
# (117, 295, 3)

# %%
test_gs = cv2.cvtColor(test, cv2.COLOR_BGR2GRAY)
test_gs.shape
# Out:
# (117, 295)

# %%
test.shape
# Out:
# (117, 295, 3)

# %%
test.dtype
# Out:
# dtype('uint8')

# %%
from qdanalysis.preprocessing import preprocess

test_gs, test_bin = preprocess(test)

# %%
plt.imshow(test_gs, cmap='gray')

# %%
plt.imshow(test_bin, cmap='gray')

# %%
from qdanalysis.strokedecomposition import simple_stroke_segment

test_strokes = simple_stroke_segment(test)
len(test_strokes)
# Out:
# (slice(13, 62, None), slice(97, 115, None))
# (slice(20, 58, None), slice(202, 218, None))
# (slice(18, 28, None), slice(216, 226, None))
# (slice(24, 56, None), slice(211, 220, None))
# (slice(24, 43, None), slice(263, 273, None))
# (slice(39, 50, None), slice(245, 264, None))
# (slice(42, 51, None), slice(261, 267, None))
# (slice(43, 54, None), slice(265, 283, None))
# (slice(39, 51, None), slice(237, 246, None))
# (slice(48, 55, None), slice(241, 251, None))
# (slice(50, 56, None), slice(260, 267, None))
# (slice(48, 59, None), slice(213, 232, None))
# (slice(54, 61, None), slice(207, 213, None))
# (slice(57, 77, None), slice(206, 216, None))
# (slice(51, 60, None), slice(246, 261, None))
# (slice(54, 65, None), slice(241, 249, None))
# (slice(55, 74, None), slice(258, 265, None))
# (slice(56, 75, None), slice(222, 238, None))
# (slice(54, 63, None), slice(230, 240, None))
# (slice(57, 61, None), slice(203, 208, None))
# (slice(52, 83, None), slice(78, 97, None))
# (slice(60, 72, None), slice(92, 102, None))
# (slice(57, 64, None), slice(196, 204, None))
# (slice(61, 68, None), slice(202, 208, None))
# (slice(59, 69, None), slice(169, 186, None))
# (slice(44, 65, None), slice(166, 193, None))
# (slice(60, 69, None), slice(185, 196, None))
# (slice(68, 75, None), slice(189, 197, None))
# (slice(68, 80, None), slice(180, 191, None))
# (slice(60, 66, None), slice(194, 198, None))
# (slice(62, 68, None), slice(198, 202, None))
# (slice(60, 67, None), slice(237, 242, None))
# (slice(64, 75, None), slice(238, 247, None))
# (slice(63, 83, None), slice(164, 181, None))
# (slice(65, 68, None), slice(193, 197, None))
# (slice(66, 72, None), slice(196, 202, None))
# (slice(66, 70, None), slice(201, 203, None))
# (slice(64, 70, None), slice(37, 45, None))
# (slice(51, 94, None), slice(26, 52, None))
# (slice(68, 79, None), slice(39, 49, None))
# (slice(67, 75, None), slice(202, 208, None))
# (slice(68, 78, None), slice(262, 280, None))
# (slice(68, 90, None), slice(81, 96, None))
# (slice(71, 96, None), slice(95, 114, None))
# (slice(74, 90, None), slice(202, 213, None))
# (slice(74, 79, None), slice(258, 265, None))
# (slice(76, 94, None), slice(30, 44, None))
# (slice(76, 83, None), slice(43, 50, None))
# (slice(79, 96, None), slice(180, 207, None))
# (slice(51, 94, None), slice(49, 81, None))
# (slice(82, 91, None), slice(43, 55, None))
# (slice(87, 98, None), slice(206, 216, None))
# 32

# %%
plt.imshow(test_strokes[26], cmap='gray')

# %%
bb
# Out:
# [(slice(13, 98, None), slice(26, 283, None))]

# %%
h, w = bb[0]

# %%
len(h)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 len(h)
#
# TypeError: object of type 'slice' has no len()

# %%
writer3030_en = cv2.imread(r'./CERUG/Writer0303_01.ppm')
plt.imshow(writer3030_en)
